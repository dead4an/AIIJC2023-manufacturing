# %%
# Модели
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier

# Пайплайн
from sklearn.pipeline import Pipeline
from sklearn.base import TransformerMixin, BaseEstimator
from sklearn.ensemble import StackingClassifier
from sklearn.model_selection import cross_val_score, train_test_split, StratifiedKFold
from sklearn.metrics import f1_score, roc_auc_score

# Данные
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from category_encoders import BinaryEncoder, OneHotEncoder
from sklearn.preprocessing import RobustScaler, StandardScaler, PowerTransformer, PolynomialFeatures, QuantileTransformer
from sklearn.utils.class_weight import compute_sample_weight

# %%
# Пути
ROOT = os.getcwd()
TRAIN_DATASET = os.path.join(ROOT, '../data/train_AIC.csv')
BALANCED_DATASET = os.path.join(ROOT, '../data/balanced_train.csv')
TEST_DATASET = os.path.join(ROOT, '../data/test_AIC.csv')
SUBMISSION_PATH = os.path.join(ROOT, '../submissions/')

def save_submission(model, subname):
    subname = os.path.join(SUBMISSION_PATH, f'{subname}.csv')
    preds = model.predict(test_df)
    submit_df = pd.DataFrame({'id': test_df.index, 'value': preds})
    submit_df.to_csv(subname, index=False)

# Загрузка
train_df = pd.read_csv(TRAIN_DATASET)
# balanced_df = pd.read_csv(BALANCED_DATASET, index_col=0)
# train_df = balanced_df
test_df = pd.read_csv(TEST_DATASET)

# first_negatives = train_df[train_df['y'] == 0][:train_df[train_df['y'] == 1]['y'].count()]
# train_df = pd.concat([train_df[train_df['y'] == 1], first_negatives])

# def random_undersample(df):
#     neg_count, pos_count = np.bincount(df['y'])
#     pos_df = df[df['y'] == 1]
#     neg_df = df[df['y'] == 0]
#     neg_df = neg_df.sample(n=pos_count, random_state=1708)
#     return pd.concat([pos_df, neg_df])

# balanced_df = random_undersample(train_df)

# Нормализация
train_df = train_df[train_df['Длительность'] < 500]
train_df = train_df[(train_df['Сумма'] > 2) & (train_df['Сумма'] < 10)]
# train_df = train_df[train_df['До поставки'] < 300]

X, y = train_df.iloc[:, :-1], train_df.iloc[:, -1]   
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
# Категориальные фичи
cat_features = [
    'Purchasing Organization', 'Delivery Option', 
    'Company Code', 'Provider', 'Provider Delivery option', 
    'Provider Purchaser', 'Operations Manager', 'Sum Fold',
    'Month1', 'Month2', 'Month3', 'Weekday', 'Material Group',
    'Purchasing Group', 'EI', 'Factory'
    ]

# Фичи на масштабирование
scale_features = [
    'Position Count', 'Duration', 'ETC Delivery',
    'Changes After Approvals', 'Order Approval 1', 'Order Approval 2',
    'Order Approval 3', 'Sum', 'Change Delivery Date 7', 'Change Delivery Date 15', 
    'Change Delivery Date 30', 'Approval Cycles', 
    'Handlers 7', 'Handlers 15', 'Handlers 30',
    'Days Between 0_1', 'Days Between 1_2', 'Days Between 2_3', 
    'Days Between 3_4', 'Days Between 4_5', 
    'Days Between 5_6', 'Days Between 6_7', 'Days Between 7_8',
    
]

# Фичи на дроп
drop_features = [
    'Material', 'Cancel Complete Release', 'Amount',
    'Delivery Date', 'Change on Paper', 
    'Category Manager', 'NRP' 
    ]

# Новые имена фич
rename_cols = [
    'Provider', 'Material', 'Category Manager', 'Operations Manager',
    'Factory', 'Purchasing Organization', 'Purchasing Group', 
    'Company Code', 'EI', 'Material Group', 'Delivery Option', 'NRP',
    'Duration', 'ETC Delivery', 'Month1', 'Month2', 'Month3', 'Weekday',
    'Sum', 'Position Count', 'Amount', 'Handlers 7', 'Handlers 15', 
    'Handlers 30', 'Order Approval 1', 'Order Approval 2', 'Order Approval 3',
    'Change Delivery Date 7', 'Change Delivery Date 15', 'Change Delivery Date 30',
    'Cancel Complete Release', 'Change on Paper', 'Delivery Date', 
    'Approval Cycles', 'Changes After Approvals', 'Days Between 0_1', 
    'Days Between 1_2', 'Days Between 2_3', 'Days Between 3_4', 'Days Between 4_5', 
    'Days Between 5_6', 'Days Between 6_7', 'Days Between 7_8'
    ]

# %%
# Препроцессоры
class DataPreprocessor(BaseEstimator, TransformerMixin):
    """ Предобработчик данных """
    def __init__(self, cat_features, scale_features,
                 drop_features, rename_cols, transform_train=True):
        self.transform_train = transform_train
        self.cat_features = cat_features

        self.bin_encoder = BinaryEncoder(cols=cat_features)
        self.robust_scaler = RobustScaler()

        self.rename_cols = rename_cols

        self.drop_features = drop_features
        self.scale_features = scale_features

    def fit(self, X, y=None):
        # Создаём копию датасета
        X_ = X.copy()
        X_.columns = self.rename_cols

        # Экстракция фич
        X_['Provider Purchaser'] = [f'{x}_{y}' for x, y in zip(X_['Provider'].values, X_['Purchasing Organization'].values)]
        X_['Provider Delivery option'] = [f'{x}_{y}' for x, y in zip(X_['Provider'].values, X_['Delivery Option'].values)]
        X_['Sum Fold'] = X_['Sum'].apply(lambda x: int(x % 10))
        
        # Нормализация
        self.robust_scaler.fit(X_[self.scale_features])

        # Категориальные фичи        
        X_ = self.bin_encoder.fit_transform(X_)

        X_ = X_.drop(self.drop_features, axis=1)
        
        return self
    
    def transform(self, X):
        # Создаём копию датасета
        X_ = X.copy()
        X_.columns = self.rename_cols

        # Экстракция фич
        X_['Provider Purchaser'] = [f'{x}_{y}' for x, y in zip(X_['Provider'].values, X_['Purchasing Organization'].values)]
        X_['Provider Delivery option'] = [f'{x}_{y}' for x, y in zip(X_['Provider'].values, X_['Delivery Option'].values)]
        X_['Sum Fold'] = X_['Sum'].apply(lambda x: x % 10)

        # Нормализация
        X_[self.scale_features] = self.robust_scaler.transform(X_[self.scale_features])

        # Категориальные фичи
        X_ = self.bin_encoder.transform(X_)

        X_ = X_.drop(self.drop_features, axis=1)

        return X_

# %%
sample_weights = compute_sample_weight(class_weight='balanced', y=y_train)

# %%
cat_params = [
    {
    # 'cat_features': cat_features,
    'learning_rate': 0.3, 
    'iterations': 1000, 
    'max_depth': 16,
    'num_leaves': 160,
    'l2_leaf_reg': 0.2,
    'auto_class_weights': 'Balanced',
    'task_type': 'GPU',
    'grow_policy': 'Lossguide'
    }
]

lgbm_params = [
    {
    'learning_rate': 0.3, 
    'n_estimators': 1500, 
    'max_depth': 16, 
    'max_bin': 160, 
    'num_leaves': 180,
    'reg_lambda': 0.2,
    'is_unbalance': True,
    'n_jobs': -1
    }
]

models = []

for index, params in enumerate(cat_params):
    cat_model = CatBoostClassifier(**params)
    models.append((f'cat_{index}', cat_model))
    
for index, params in enumerate(lgbm_params):
    lgbm_model = LGBMClassifier(**params)
    models.append((f'lgbm_{index}', lgbm_model))

# %%
# final_estimator_params = {
#     'learning_rate': 0.3, 
#     'n_estimators': 1500, 
#     'max_depth': 12, 
#     'max_bin': 160, 
#     'max_leaves': 128,
#     'reg_lambda': 0.2,
#     'n_jobs': -1,
#     'tree_method': 'gpu_hist',
#     'random_state': 1001
#     }

# final_estimator = XGBClassifier(**final_estimator_params)
data_preprocessor = DataPreprocessor(cat_features, scale_features, drop_features, rename_cols)
stack = StackingClassifier(estimators=models, verbose=1)
pipeline = Pipeline([
    ('data', data_preprocessor),
    ('model', stack)
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# 0:	learn: 0.5758600	total: 74.8ms	remaining: 1m 14s
# 1:	learn: 0.5001181	total: 159ms	remaining: 1m 19s
# 2:	learn: 0.4353514	total: 238ms	remaining: 1m 19s
# 3:	learn: 0.4105956	total: 316ms	remaining: 1m 18s
# 4:	learn: 0.3926414	total: 397ms	remaining: 1m 18s
# 5:	learn: 0.3650508	total: 471ms	remaining: 1m 18s
# 6:	learn: 0.3536452	total: 544ms	remaining: 1m 17s
# 7:	learn: 0.3435353	total: 619ms	remaining: 1m 16s
# 8:	learn: 0.3272213	total: 692ms	remaining: 1m 16s
# 9:	learn: 0.3194301	total: 770ms	remaining: 1m 16s
# 10:	learn: 0.3117362	total: 846ms	remaining: 1m 16s
# 11:	learn: 0.3014060	total: 917ms	remaining: 1m 15s
# 12:	learn: 0.2941542	total: 992ms	remaining: 1m 15s
# 13:	learn: 0.2885355	total: 1.07s	remaining: 1m 15s
# 14:	learn: 0.2830824	total: 1.14s	remaining: 1m 14s
# 15:	learn: 0.2767345	total: 1.22s	remaining: 1m 14s
# 16:	learn: 0.2712019	total: 1.29s	remaining: 1m 14s
# 17:	learn: 0.2660974	total: 1.37s	remaining: 1m 14s
# 18:	learn: 0.2605461	total: 1.44s	remaining: 1m 14s
# 19:	learn: 0.2565333	total: 1.53s	remaining: 1m 14s
# 20:	learn: 0.2529835	total: 1.6s	remaining: 1m 14s
# 21:	learn: 0.2488054	total: 1.68s	remaining: 1m 14s
# 22:	learn: 0.2451258	total: 1.75s	remaining: 1m 14s
# 23:	learn: 0.2413799	total: 1.82s	remaining: 1m 14s
# 24:	learn: 0.2370006	total: 1.89s	remaining: 1m 13s
# 25:	learn: 0.2331863	total: 1.97s	remaining: 1m 13s
# 26:	learn: 0.2292212	total: 2.06s	remaining: 1m 14s
# 27:	learn: 0.2256479	total: 2.13s	remaining: 1m 14s
# 28:	learn: 0.2223569	total: 2.21s	remaining: 1m 13s
# 29:	learn: 0.2194045	total: 2.29s	remaining: 1m 13s
# 30:	learn: 0.2167457	total: 2.36s	remaining: 1m 13s
# 31:	learn: 0.2138964	total: 2.43s	remaining: 1m 13s
# 32:	learn: 0.2108836	total: 2.5s	remaining: 1m 13s
# 33:	learn: 0.2078970	total: 2.58s	remaining: 1m 13s
# 34:	learn: 0.2056195	total: 2.64s	remaining: 1m 12s
# 35:	learn: 0.2026813	total: 2.71s	remaining: 1m 12s
# 36:	learn: 0.2004803	total: 2.79s	remaining: 1m 12s
# 37:	learn: 0.1970901	total: 2.86s	remaining: 1m 12s
# 38:	learn: 0.1948286	total: 2.93s	remaining: 1m 12s
# 39:	learn: 0.1922093	total: 3s	remaining: 1m 12s
# 40:	learn: 0.1897616	total: 3.07s	remaining: 1m 11s
# 41:	learn: 0.1875752	total: 3.15s	remaining: 1m 11s
# 42:	learn: 0.1852202	total: 3.22s	remaining: 1m 11s
# 43:	learn: 0.1829535	total: 3.28s	remaining: 1m 11s
# 44:	learn: 0.1811451	total: 3.35s	remaining: 1m 11s
# 45:	learn: 0.1792465	total: 3.42s	remaining: 1m 10s
# 46:	learn: 0.1771999	total: 3.49s	remaining: 1m 10s
# 47:	learn: 0.1749231	total: 3.56s	remaining: 1m 10s
# 48:	learn: 0.1727138	total: 3.63s	remaining: 1m 10s
# 49:	learn: 0.1708860	total: 3.7s	remaining: 1m 10s
# 50:	learn: 0.1692732	total: 3.76s	remaining: 1m 10s
# 51:	learn: 0.1671630	total: 3.83s	remaining: 1m 9s
# 52:	learn: 0.1652897	total: 3.9s	remaining: 1m 9s
# 53:	learn: 0.1634641	total: 3.97s	remaining: 1m 9s
# 54:	learn: 0.1614500	total: 4.04s	remaining: 1m 9s
# 55:	learn: 0.1596503	total: 4.12s	remaining: 1m 9s
# 56:	learn: 0.1577927	total: 4.2s	remaining: 1m 9s
# 57:	learn: 0.1561629	total: 4.27s	remaining: 1m 9s
# 58:	learn: 0.1544621	total: 4.35s	remaining: 1m 9s
# 59:	learn: 0.1526327	total: 4.42s	remaining: 1m 9s
# 60:	learn: 0.1512054	total: 4.49s	remaining: 1m 9s
# 61:	learn: 0.1493298	total: 4.56s	remaining: 1m 9s
# 62:	learn: 0.1477418	total: 4.65s	remaining: 1m 9s
# 63:	learn: 0.1458842	total: 4.74s	remaining: 1m 9s
# 64:	learn: 0.1446751	total: 4.82s	remaining: 1m 9s
# 65:	learn: 0.1434130	total: 4.88s	remaining: 1m 9s
# 66:	learn: 0.1419547	total: 4.95s	remaining: 1m 8s
# 67:	learn: 0.1403158	total: 5.02s	remaining: 1m 8s
# 68:	learn: 0.1386742	total: 5.09s	remaining: 1m 8s
# 69:	learn: 0.1373276	total: 5.16s	remaining: 1m 8s
# 70:	learn: 0.1359308	total: 5.24s	remaining: 1m 8s
# 71:	learn: 0.1346857	total: 5.33s	remaining: 1m 8s
# 72:	learn: 0.1333260	total: 5.41s	remaining: 1m 8s
# 73:	learn: 0.1316012	total: 5.49s	remaining: 1m 8s
# 74:	learn: 0.1302302	total: 5.56s	remaining: 1m 8s
# 75:	learn: 0.1287286	total: 5.64s	remaining: 1m 8s
# 76:	learn: 0.1275224	total: 5.71s	remaining: 1m 8s
# 77:	learn: 0.1262438	total: 5.77s	remaining: 1m 8s
# 78:	learn: 0.1251313	total: 5.84s	remaining: 1m 8s
# 79:	learn: 0.1238124	total: 5.92s	remaining: 1m 8s
# 831:	learn: 0.0018158	total: 1m 2s	remaining: 12.6s
# 832:	learn: 0.0018120	total: 1m 2s	remaining: 12.5s
# 833:	learn: 0.0018088	total: 1m 2s	remaining: 12.5s
# 834:	learn: 0.0018062	total: 1m 2s	remaining: 12.4s
# 835:	learn: 0.0018028	total: 1m 2s	remaining: 12.3s
# 836:	learn: 0.0017998	total: 1m 2s	remaining: 12.2s
# 837:	learn: 0.0017968	total: 1m 2s	remaining: 12.2s
# 838:	learn: 0.0017941	total: 1m 3s	remaining: 12.1s
# 839:	learn: 0.0017919	total: 1m 3s	remaining: 12s
# 840:	learn: 0.0017885	total: 1m 3s	remaining: 11.9s
# 841:	learn: 0.0017858	total: 1m 3s	remaining: 11.9s
# 842:	learn: 0.0017826	total: 1m 3s	remaining: 11.8s
# 843:	learn: 0.0017796	total: 1m 3s	remaining: 11.7s
# 844:	learn: 0.0017770	total: 1m 3s	remaining: 11.6s
# 845:	learn: 0.0017751	total: 1m 3s	remaining: 11.6s
# 846:	learn: 0.0017724	total: 1m 3s	remaining: 11.5s
# 847:	learn: 0.0017699	total: 1m 3s	remaining: 11.4s
# 848:	learn: 0.0017665	total: 1m 3s	remaining: 11.3s
# 849:	learn: 0.0017644	total: 1m 3s	remaining: 11.3s
# 850:	learn: 0.0017625	total: 1m 3s	remaining: 11.2s
# 851:	learn: 0.0017601	total: 1m 4s	remaining: 11.1s
# 852:	learn: 0.0017578	total: 1m 4s	remaining: 11s
# 853:	learn: 0.0017549	total: 1m 4s	remaining: 11s
# 854:	learn: 0.0017518	total: 1m 4s	remaining: 10.9s
# 855:	learn: 0.0017493	total: 1m 4s	remaining: 10.8s
# 856:	learn: 0.0017467	total: 1m 4s	remaining: 10.7s
# 857:	learn: 0.0017441	total: 1m 4s	remaining: 10.7s
# 858:	learn: 0.0017420	total: 1m 4s	remaining: 10.6s
# 859:	learn: 0.0017393	total: 1m 4s	remaining: 10.5s
# 860:	learn: 0.0017366	total: 1m 4s	remaining: 10.4s
# 861:	learn: 0.0017341	total: 1m 4s	remaining: 10.4s
# 862:	learn: 0.0017315	total: 1m 4s	remaining: 10.3s
# 863:	learn: 0.0017281	total: 1m 4s	remaining: 10.2s
# 864:	learn: 0.0017259	total: 1m 5s	remaining: 10.2s
# 865:	learn: 0.0017235	total: 1m 5s	remaining: 10.1s
# 866:	learn: 0.0017216	total: 1m 5s	remaining: 10s
# 867:	learn: 0.0017194	total: 1m 5s	remaining: 9.93s
# 868:	learn: 0.0017171	total: 1m 5s	remaining: 9.85s
# 869:	learn: 0.0017139	total: 1m 5s	remaining: 9.78s
# 870:	learn: 0.0017112	total: 1m 5s	remaining: 9.7s
# 871:	learn: 0.0017092	total: 1m 5s	remaining: 9.63s
# 872:	learn: 0.0017063	total: 1m 5s	remaining: 9.55s
# 873:	learn: 0.0017040	total: 1m 5s	remaining: 9.47s
# 874:	learn: 0.0017014	total: 1m 5s	remaining: 9.4s
# 875:	learn: 0.0016989	total: 1m 5s	remaining: 9.32s
# 876:	learn: 0.0016965	total: 1m 5s	remaining: 9.25s
# 877:	learn: 0.0016941	total: 1m 6s	remaining: 9.17s
# 878:	learn: 0.0016919	total: 1m 6s	remaining: 9.1s
# 879:	learn: 0.0016904	total: 1m 6s	remaining: 9.02s
# 880:	learn: 0.0016879	total: 1m 6s	remaining: 8.95s
# 881:	learn: 0.0016866	total: 1m 6s	remaining: 8.87s
# 882:	learn: 0.0016839	total: 1m 6s	remaining: 8.79s
# 883:	learn: 0.0016821	total: 1m 6s	remaining: 8.72s
# 884:	learn: 0.0016801	total: 1m 6s	remaining: 8.64s
# 885:	learn: 0.0016776	total: 1m 6s	remaining: 8.57s
# 886:	learn: 0.0016760	total: 1m 6s	remaining: 8.49s
# 887:	learn: 0.0016742	total: 1m 6s	remaining: 8.42s
# 888:	learn: 0.0016715	total: 1m 6s	remaining: 8.34s
# 889:	learn: 0.0016688	total: 1m 6s	remaining: 8.27s
# 890:	learn: 0.0016656	total: 1m 6s	remaining: 8.19s
# 891:	learn: 0.0016633	total: 1m 7s	remaining: 8.12s
# 892:	learn: 0.0016619	total: 1m 7s	remaining: 8.04s
# 893:	learn: 0.0016595	total: 1m 7s	remaining: 7.97s
# 894:	learn: 0.0016574	total: 1m 7s	remaining: 7.9s
# 895:	learn: 0.0016556	total: 1m 7s	remaining: 7.82s
# 896:	learn: 0.0016534	total: 1m 7s	remaining: 7.75s
# 897:	learn: 0.0016498	total: 1m 7s	remaining: 7.67s
# 898:	learn: 0.0016477	total: 1m 7s	remaining: 7.6s
# 899:	learn: 0.0016453	total: 1m 7s	remaining: 7.52s
# 900:	learn: 0.0016433	total: 1m 7s	remaining: 7.45s
# 901:	learn: 0.0016414	total: 1m 7s	remaining: 7.37s
# 902:	learn: 0.0016392	total: 1m 7s	remaining: 7.29s
# 903:	learn: 0.0016375	total: 1m 7s	remaining: 7.22s
# 904:	learn: 0.0016356	total: 1m 8s	remaining: 7.14s
# 905:	learn: 0.0016334	total: 1m 8s	remaining: 7.07s
# 906:	learn: 0.0016306	total: 1m 8s	remaining: 6.99s
# 907:	learn: 0.0016294	total: 1m 8s	remaining: 6.92s
# 908:	learn: 0.0016270	total: 1m 8s	remaining: 6.84s
# 909:	learn: 0.0016242	total: 1m 8s	remaining: 6.77s
# 910:	learn: 0.0016223	total: 1m 8s	remaining: 6.69s
# 911:	learn: 0.0016205	total: 1m 8s	remaining: 6.62s
# 912:	learn: 0.0016182	total: 1m 8s	remaining: 6.54s
# 913:	learn: 0.0016159	total: 1m 8s	remaining: 6.46s
# 914:	learn: 0.0016137	total: 1m 8s	remaining: 6.39s
# 915:	learn: 0.0016122	total: 1m 8s	remaining: 6.31s
# 916:	learn: 0.0016102	total: 1m 8s	remaining: 6.24s
# 917:	learn: 0.0016089	total: 1m 9s	remaining: 6.16s
# 918:	learn: 0.0016071	total: 1m 9s	remaining: 6.09s
# 919:	learn: 0.0016046	total: 1m 9s	remaining: 6.01s
# 920:	learn: 0.0016027	total: 1m 9s	remaining: 5.94s
# 921:	learn: 0.0016011	total: 1m 9s	remaining: 5.86s
# 922:	learn: 0.0015984	total: 1m 9s	remaining: 5.79s
# 923:	learn: 0.0015966	total: 1m 9s	remaining: 5.71s
# 924:	learn: 0.0015943	total: 1m 9s	remaining: 5.63s
# 925:	learn: 0.0015920	total: 1m 9s	remaining: 5.56s
# 926:	learn: 0.0015906	total: 1m 9s	remaining: 5.49s
# 927:	learn: 0.0015877	total: 1m 9s	remaining: 5.41s
# 928:	learn: 0.0015852	total: 1m 9s	remaining: 5.33s
# 929:	learn: 0.0015836	total: 1m 9s	remaining: 5.26s
# 930:	learn: 0.0015817	total: 1m 9s	remaining: 5.18s
# ...
# 909:	learn: 0.0012647	total: 1m 9s	remaining: 6.89s
# 910:	learn: 0.0012635	total: 1m 9s	remaining: 6.82s
# 911:	learn: 0.0012619	total: 1m 9s	remaining: 6.74s
# 912:	learn: 0.0012609	total: 1m 9s	remaining: 6.66s
# 913:	learn: 0.0012596	total: 1m 10s	remaining: 6.59s
# 914:	learn: 0.0012584	total: 1m 10s	remaining: 6.51s
# 915:	learn: 0.0012570	total: 1m 10s	remaining: 6.43s
# 916:	learn: 0.0012557	total: 1m 10s	remaining: 6.36s
# 917:	learn: 0.0012548	total: 1m 10s	remaining: 6.28s
# 918:	learn: 0.0012535	total: 1m 10s	remaining: 6.21s
# 919:	learn: 0.0012524	total: 1m 10s	remaining: 6.13s
# 920:	learn: 0.0012511	total: 1m 10s	remaining: 6.05s
# 921:	learn: 0.0012496	total: 1m 10s	remaining: 5.98s
# 922:	learn: 0.0012488	total: 1m 10s	remaining: 5.9s
# 923:	learn: 0.0012476	total: 1m 10s	remaining: 5.82s
# 924:	learn: 0.0012463	total: 1m 10s	remaining: 5.75s
# 925:	learn: 0.0012454	total: 1m 10s	remaining: 5.67s
# 926:	learn: 0.0012440	total: 1m 11s	remaining: 5.59s
# 927:	learn: 0.0012425	total: 1m 11s	remaining: 5.52s
# 928:	learn: 0.0012414	total: 1m 11s	remaining: 5.44s
# 929:	learn: 0.0012401	total: 1m 11s	remaining: 5.36s
# 930:	learn: 0.0012385	total: 1m 11s	remaining: 5.29s
# 931:	learn: 0.0012375	total: 1m 11s	remaining: 5.21s
# 932:	learn: 0.0012361	total: 1m 11s	remaining: 5.13s
# 933:	learn: 0.0012351	total: 1m 11s	remaining: 5.06s
# 934:	learn: 0.0012340	total: 1m 11s	remaining: 4.98s
# 935:	learn: 0.0012330	total: 1m 11s	remaining: 4.9s
# 936:	learn: 0.0012318	total: 1m 11s	remaining: 4.83s
# 937:	learn: 0.0012305	total: 1m 11s	remaining: 4.75s
# 938:	learn: 0.0012293	total: 1m 11s	remaining: 4.67s
# 939:	learn: 0.0012280	total: 1m 12s	remaining: 4.6s
# 940:	learn: 0.0012267	total: 1m 12s	remaining: 4.52s
# 941:	learn: 0.0012257	total: 1m 12s	remaining: 4.44s
# 942:	learn: 0.0012249	total: 1m 12s	remaining: 4.37s
# 943:	learn: 0.0012237	total: 1m 12s	remaining: 4.29s
# 944:	learn: 0.0012227	total: 1m 12s	remaining: 4.21s
# 945:	learn: 0.0012215	total: 1m 12s	remaining: 4.14s
# 946:	learn: 0.0012205	total: 1m 12s	remaining: 4.06s
# 947:	learn: 0.0012195	total: 1m 12s	remaining: 3.98s
# 948:	learn: 0.0012184	total: 1m 12s	remaining: 3.9s
# 949:	learn: 0.0012173	total: 1m 12s	remaining: 3.83s
# 950:	learn: 0.0012161	total: 1m 12s	remaining: 3.75s
# 951:	learn: 0.0012149	total: 1m 12s	remaining: 3.67s
# 952:	learn: 0.0012135	total: 1m 12s	remaining: 3.6s
# 953:	learn: 0.0012125	total: 1m 13s	remaining: 3.52s
# 954:	learn: 0.0012113	total: 1m 13s	remaining: 3.44s
# 955:	learn: 0.0012101	total: 1m 13s	remaining: 3.37s
# 956:	learn: 0.0012092	total: 1m 13s	remaining: 3.29s
# 957:	learn: 0.0012083	total: 1m 13s	remaining: 3.22s
# 958:	learn: 0.0012074	total: 1m 13s	remaining: 3.14s
# 959:	learn: 0.0012064	total: 1m 13s	remaining: 3.06s
# 960:	learn: 0.0012054	total: 1m 13s	remaining: 2.99s
# 961:	learn: 0.0012047	total: 1m 13s	remaining: 2.91s
# 962:	learn: 0.0012035	total: 1m 13s	remaining: 2.83s
# 963:	learn: 0.0012027	total: 1m 13s	remaining: 2.76s
# 964:	learn: 0.0012013	total: 1m 13s	remaining: 2.68s
# 965:	learn: 0.0012005	total: 1m 13s	remaining: 2.6s
# 966:	learn: 0.0011995	total: 1m 14s	remaining: 2.53s
# 967:	learn: 0.0011985	total: 1m 14s	remaining: 2.45s
# 968:	learn: 0.0011976	total: 1m 14s	remaining: 2.37s
# 969:	learn: 0.0011965	total: 1m 14s	remaining: 2.3s
# 970:	learn: 0.0011954	total: 1m 14s	remaining: 2.22s
# 971:	learn: 0.0011945	total: 1m 14s	remaining: 2.14s
# 972:	learn: 0.0011935	total: 1m 14s	remaining: 2.07s
# 973:	learn: 0.0011925	total: 1m 14s	remaining: 1.99s
# 974:	learn: 0.0011916	total: 1m 14s	remaining: 1.91s
# 975:	learn: 0.0011904	total: 1m 14s	remaining: 1.84s
# 976:	learn: 0.0011894	total: 1m 14s	remaining: 1.76s
# 977:	learn: 0.0011883	total: 1m 14s	remaining: 1.68s
# 978:	learn: 0.0011873	total: 1m 14s	remaining: 1.61s
# 979:	learn: 0.0011862	total: 1m 15s	remaining: 1.53s
# 980:	learn: 0.0011851	total: 1m 15s	remaining: 1.45s
# 981:	learn: 0.0011840	total: 1m 15s	remaining: 1.38s
# 982:	learn: 0.0011830	total: 1m 15s	remaining: 1.3s
# 983:	learn: 0.0011823	total: 1m 15s	remaining: 1.23s
# 984:	learn: 0.0011814	total: 1m 15s	remaining: 1.15s
# 985:	learn: 0.0011806	total: 1m 15s	remaining: 1.07s
# 986:	learn: 0.0011798	total: 1m 15s	remaining: 996ms
# 987:	learn: 0.0011790	total: 1m 15s	remaining: 919ms
# 988:	learn: 0.0011779	total: 1m 15s	remaining: 843ms
# 989:	learn: 0.0011767	total: 1m 15s	remaining: 766ms
# 990:	learn: 0.0011756	total: 1m 15s	remaining: 689ms
# 991:	learn: 0.0011746	total: 1m 16s	remaining: 613ms
# 992:	learn: 0.0011736	total: 1m 16s	remaining: 536ms
# 993:	learn: 0.0011730	total: 1m 16s	remaining: 460ms
# 994:	learn: 0.0011718	total: 1m 16s	remaining: 383ms
# 995:	learn: 0.0011709	total: 1m 16s	remaining: 306ms
# 996:	learn: 0.0011701	total: 1m 16s	remaining: 230ms
# 997:	learn: 0.0011694	total: 1m 16s	remaining: 153ms
# 998:	learn: 0.0011688	total: 1m 16s	remaining: 76.6ms
# 999:	learn: 0.0011678	total: 1m 16s	remaining: 0us
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 23276, number of negative: 138724
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014144 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2320
# [LightGBM] [Info] Number of data points in the train set: 162000, number of used features: 79
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.143679 -> initscore=-1.785064
# [LightGBM] [Info] Start training from score -1.785064
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 23277, number of negative: 138723
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013311 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2330
# [LightGBM] [Info] Number of data points in the train set: 162000, number of used features: 79
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.143685 -> initscore=-1.785013
# [LightGBM] [Info] Start training from score -1.785013
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 23277, number of negative: 138723
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013910 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2336
# [LightGBM] [Info] Number of data points in the train set: 162000, number of used features: 79
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.143685 -> initscore=-1.785013
# [LightGBM] [Info] Start training from score -1.785013
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 23277, number of negative: 138723
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.015883 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2322
# [LightGBM] [Info] Number of data points in the train set: 162000, number of used features: 79
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.143685 -> initscore=-1.785013
# [LightGBM] [Info] Start training from score -1.785013
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Number of positive: 23277, number of negative: 138723
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.012218 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 2336
# [LightGBM] [Info] Number of data points in the train set: 162000, number of used features: 79
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.143685 -> initscore=-1.785013
# [LightGBM] [Info] Start training from score -1.785013
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# Pipeline(steps=[('data',
#                  DataPreprocessor(cat_features=['Purchasing Organization',
#                                                 'Delivery Option',
#                                                 'Company Code', 'Provider',
#                                                 'Provider Delivery option',
#                                                 'Provider Purchaser',
#                                                 'Operations Manager',
#                                                 'Sum Fold'],
#                                   drop_features=['Material',
#                                                  'Cancel Complete Release',
#                                                  'Amount', 'Material Group',
#                                                  'Month1', 'Month2', 'Month3',
#                                                  'Weekday', 'Delivery Date',
#                                                  'Change on Paper',
#                                                  'Category...
#                                                   'Days Between 3_4',
#                                                   'Days Between 4_5',
#                                                   'Days Between 5_6',
#                                                   'Days Between 6_7',
#                                                   'Days Between 7_8'])),
#                 ('model',
#                  StackingClassifier(estimators=[('cat_0',
#                                                  <catboost.core.CatBoostClassifier object at 0x0000017957B5CF10>),
#                                                 ('lgbm_0',
#                                                  LGBMClassifier(is_unbalance=True,
#                                                                 learning_rate=0.3,
#                                                                 max_bin=160,
#                                                                 max_depth=16,
#                                                                 n_estimators=1500,
#                                                                 n_jobs=-1,
#                                                                 num_leaves=180,
#                                                                 reg_lambda=0.2))],
#                                     verbose=1))])

# %%
preds = pipeline.predict(X_test)

# %%
preds = pipeline.predict(X_test)
print(f1_score(y_test, preds, average='macro'))
print(roc_auc_score(y_test, preds))
# Out:
# 0.8901746667841965
# 0.8704183455848186

# %%
preds = pipeline.predict(test_df)

# %%
save_submission(pipeline, 'submission_stack')
